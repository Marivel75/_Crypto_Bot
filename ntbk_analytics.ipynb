# %% [markdown]
# # 📊 Analyse et Visualisation des Données Crypto Bot
#
# Ce notebook permet d'analyser et visualiser les données OHLCV collectées par le Crypto Bot.

# %%
# Dans une cellule de ton notebook
from src.analytics.db_inspector import DBInspector
from src.analytics.technical_calculator import TechnicalCalculator
from src.analytics.plot_manager import PlotManager


inspector = DBInspector()
technical_calculator = TechnicalCalculator()
plot_manager = PlotManager()

chosen_symbol = 'BTC/USDT'
limit = 100

global_data = inspector.get_all_ohlcv_data()
crypto_data = inspector.get_ohlcv_data_for_symbol(chosen_symbol)
rsi_serie = technical_calculator.calculate_rsi(crypto_data, max_values=limit)


plot_manager.plot_ohlcv(crypto_data, limit)
print('-'*55)
plot_manager.plot_rsi(crypto_data, rsi_serie=rsi_serie,window=20,limit=limit)
print('-'*55)
plot_manager.plot_sma(crypto_data,window=20,limit=limit)
# Out:
# 2026-02-10 20:07:21,270 - crypto_bot - INFO - Récupération de toutes les données OHLCV...
# 2026-02-10 20:07:21,333 - crypto_bot - INFO - Données OHLCV récupérées avec succès. Forme: (5100, 16)
# 2026-02-10 20:07:21,335 - crypto_bot - INFO - Récupération des données OHLCV pour le symbole BTC/USDT...
# 2026-02-10 20:07:21,340 - crypto_bot - INFO - Données OHLCV récupérées avec succès. Forme: (1200, 16)
# 2026-02-10 20:07:21,347 - crypto_bot - WARNING - Limitation du calcul RSI à 100 valeurs (sur 1200 disponibles).
# 2026-02-10 20:07:21,352 - crypto_bot - INFO - Tracé du graphique OHLCV (type: candle)
# 2026-02-10 20:07:21,353 - crypto_bot - WARNING - Trop de données à tracer (1200 bougies). Seules les 100 dernières seront affichées pour garantir la lisibilité.
# 2026-02-10 20:07:21,581 - crypto_bot - INFO - Tracé du graphique avec RSI (fenêtre: 20)
# -------------------------------------------------------
# 2026-02-10 20:07:21,721 - crypto_bot - INFO - Graphique RSI tracé avec succès: 86 bougies, RSI(20)
# 2026-02-10 20:07:21,722 - crypto_bot - INFO - Tracé du graphique avec SMA, window : 20
# -------------------------------------------------------
# 2026-02-10 20:07:21,891 - crypto_bot - INFO - Graphique tracé avec succès: 100 bougies, SMA20
