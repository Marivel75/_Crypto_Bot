# %% [markdown]
# # 📊 Analyse et Visualisation des Données Crypto Bot
#
# Ce notebook permet d'analyser et visualiser les données OHLCV collectées par le Crypto Bot.

# %%
from src.analytics.db_inspector import DBInspector
from src.analytics.technical_calculator import TechnicalCalculator
from src.analytics.technical_signals import TechnicalSignals
from src.analytics.plot_manager import PlotManager

inspector = DBInspector()
calculator = TechnicalCalculator()
plot_manager = PlotManager()
signals = TechnicalSignals()


chosen_symbol = 'BTC/USDT'
limit = 100
window = 20
timeframe = "1d"

# Récupération des données
global_data = inspector.get_all_ohlcv_data()
crypto_data = inspector.get_ohlcv_data_for_symbol(chosen_symbol)




# # Tracer le graphique OHLCV
# plot_manager.plot_ohlcv(crypto_data, limit=limit)
# print('-'*55)

# # Tracer le graphique RSI
# plot_manager.plot_rsi(crypto_data, window=window, limit=limit)
# print('-'*55)

# # Tracer le graphique SMA
# plot_manager.plot_sma(crypto_data, window=window, limit=limit)
# print('-'*55)

# # Tracer le graphique EMA
# plot_manager.plot_ema(crypto_data, window=window, limit=limit)

# # Section MACD
# plot_manager.plot_macd(crypto_data, limit=limit)

# Section Bandes de Bollinger
# b_bands = calculator.calculate_bollinger_bands(crypto_data)
# plot_manager.plot_bollinger_bands(crypto_data, b_bands, limit=limit)
# Out:
# 2026-02-12 20:22:27,652 - crypto_bot - INFO - Récupération de toutes les données OHLCV...
# 2026-02-12 20:22:27,735 - crypto_bot - INFO - Données OHLCV récupérées avec succès. Forme: (9298, 16)
# 2026-02-12 20:22:27,738 - crypto_bot - INFO - Récupération des données OHLCV pour le symbole BTC/USDT...
# 2026-02-12 20:22:27,747 - crypto_bot - INFO - Données OHLCV récupérées avec succès. Forme: (2100, 16)
# 2026-02-12 20:22:27,760 - crypto_bot - INFO - Tracé du graphique avec Bandes de Bollinger (window: 20, std: 2.0)
